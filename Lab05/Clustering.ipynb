# %% [markdown]
# # KMeans

# %%
import matplotlib.pyplot as plt

x = [4, 5, 10, 4, 3, 11, 14, 6, 10, 12]
y = [21, 19, 24, 17, 16, 25, 24, 22, 21, 21]

plt.scatter(x, y)
plt.show()

# %%
from sklearn.cluster import KMeans

data = list(zip(x, y))
inertias = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(data)
    inertias.append(kmeans.inertia_)

plt.plot(range(1, 11), inertias, marker='o')
plt.title('Elbow method')
plt.xlabel('Number of cluster')
plt.ylabel('Inertia')
plt.show()
# Out:
# c:\Users\minhh\miniconda3\envs\myCondaEnv\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\minhh\miniconda3\envs\myCondaEnv\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\minhh\miniconda3\envs\myCondaEnv\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %% [markdown]
# dựa trên biểu đồ này chúng ta nên chọn k = 2 để tiến hành gom nhóm
# bằng giải thuật kmeans

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(data)
# Out:
# c:\Users\minhh\miniconda3\envs\myCondaEnv\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\minhh\miniconda3\envs\myCondaEnv\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
plt.scatter(x, y, c=kmeans.labels_)
plt.show()

# %% [markdown]
# # Agglomerative Clustering

# %%
data
# Out:
# [(4, 21),
#  (5, 19),
#  (10, 24),
#  (4, 17),
#  (3, 16),
#  (11, 25),
#  (14, 24),
#  (6, 22),
#  (10, 21),
#  (12, 21)]

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

linkage_data = linkage(data, method='ward', metric='euclidean')
dendrogram(linkage_data)

plt.show()

# %% [markdown]
# # Bài Tập

# %%
import pandas as pd

df = pd.read_csv('USArrests.csv')
states = df.iloc[:, 0]
X = df.iloc[:, 1:]
X.head()
# Out:
#    Murder  Assault  UrbanPop  Rape
# 0    13.2      236        58  21.2
# 1    10.0      263        48  44.5
# 2     8.1      294        80  31.0
# 3     8.8      190        50  19.5
# 4     9.0      276        91  40.6

# %%
name.head()
# Out:
# 0       Alabama
# 1        Alaska
# 2       Arizona
# 3      Arkansas
# 4    California
# Name: Unnamed: 0, dtype: object

# %%
from sklearn.preprocessing import scale 
X = pd.DataFrame(scale(X), index=X.index, columns=X.columns)
X.head()
# Out:
#      Murder   Assault  UrbanPop      Rape
# 0  1.255179  0.790787 -0.526195 -0.003451
# 1  0.513019  1.118060 -1.224067  2.509424
# 2  0.072361  1.493817  1.009122  1.053466
# 3  0.234708  0.233212 -1.084492 -0.186794
# 4  0.281093  1.275635  1.776781  2.088814

# %%
inertias = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(X)
    inertias.append(kmeans.inertia_)

plt.plot(range(1, 11), inertias, marker='o')
plt.title('Elbow method')
plt.xlabel('Number of cluster')
plt.ylabel('Inertia')
plt.show()
# Out:
# c:\Users\minhh\miniconda3\envs\myCondaEnv\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\minhh\miniconda3\envs\myCondaEnv\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\minhh\miniconda3\envs\myCondaEnv\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
kmeans = KMeans(n_clusters=4)

kmeans.fit(X)
# Out:
# c:\Users\minhh\miniconda3\envs\myCondaEnv\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\minhh\miniconda3\envs\myCondaEnv\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4)

# %%
y_pred = kmeans.predict(X)
y_pred
# Out:
# array([0, 3, 3, 0, 3, 3, 1, 1, 3, 0, 1, 2, 3, 1, 2, 1, 2, 0, 2, 3, 1, 3,
#        2, 0, 3, 2, 2, 3, 2, 1, 3, 3, 0, 2, 1, 1, 1, 1, 1, 0, 2, 0, 3, 1,
#        2, 1, 1, 2, 2, 1])

# %%
plt.figure(figsize=(10, 5))
plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=kmeans.labels_, s=120)

for i, state in enumerate(states):
    plt.text(X.iloc[i, 0], X.iloc[i, 1], state, fontsize=6, ha='right')

plt.title('Scatter Plot with State Names')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.grid(True)
plt.show()
